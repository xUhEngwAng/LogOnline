# %%
import os
import pandas as pd
import torch

path = '../data/BGL/BGL_parsed_result_04.csv'
print(os.path.isfile(path))
# Out:
# True

# %%
BGL_parsed_result = pd.read_csv(path)
BGL_parsed_result.fillna({'Templates': ''}, inplace=True)
BGL_parsed_result.head()
# Out:
#    EventId                                 Templates Parameters  \
# 0  1750000  instruction cache parity error corrected         []
# 1  1750000  instruction cache parity error corrected         []
# 2  1750000  instruction cache parity error corrected         []
# 3  1750000  instruction cache parity error corrected         []
# 4  1750000  instruction cache parity error corrected         []
#
#                                  LogMessage  Anomaly   Timestamp  \
# 0  instruction cache parity error corrected    False  1117838570
# 1  instruction cache parity error corrected    False  1117838570
# 2  instruction cache parity error corrected    False  1117838570
# 3  instruction cache parity error corrected    False  1117838570
# 4  instruction cache parity error corrected    False  1117838570
#
#                Session
# 0  R02-M1-N0-C:J12-U11
# 1  R02-M1-N0-C:J12-U11
# 2  R02-M1-N0-C:J12-U11
# 3  R02-M1-N0-C:J12-U11
# 4  R02-M1-N0-C:J12-U11

# %%
from vocab import buildVocab

pretrain_path = '../data/wiki-news-300d-1M.vec'
embedding_matrix = buildVocab(BGL_parsed_result, pretrain_path)
# Out:
# 2023-02-16 20:30:27,746 - INFO - buildVocab identified 1035 unique tokens in structured log Dataframe.
# 2023-02-16 20:31:45,950 - INFO - 802 tokens can be converted to their corresponding semantic embeddings.
# 2023-02-16 20:31:45,953 - INFO - Number of out-of-vocabulary words is 233.

# %%
from partition import partition

filter_abnormal = True
partition_method = 'timestamp'
session_size = 200
train_ratio = 0.01

session_train, session_test, num_classes = partition(BGL_parsed_result, partition_method, train_ratio, filter_abnormal, session_size)
print(f'Training data has {num_classes} unique templates.')
# Out:
# 2023-02-16 20:33:17,731 - INFO - filter_abnormal enabled when creating training data.
# 2023-02-16 20:33:27,075 - INFO - partitionByOrder done, 23591 sessions are generated.
# 2023-02-16 20:33:27,077 - INFO - Sequential Partitioning done. 1686 event ids are identified.
# 2023-02-16 20:33:27,078 - INFO - Number of training and testing sessions are 237 and 23354
# Training data has 48 unique templates.

# %%
# Obtain unique templates of the training data
training_eventid_templates = {}
testing_eventid_templates = {}

for ind, event_id in enumerate(BGL_parsed_result['EventId']):
    if num_classes <= event_id:
        testing_eventid_templates.setdefault(event_id, (BGL_parsed_result['Templates'][ind], BGL_parsed_result['TokensId'][ind]))
    else:
        training_eventid_templates.setdefault(event_id, (BGL_parsed_result['Templates'][ind], BGL_parsed_result['TokensId'][ind]))
        
uniq_training_templates = list(training_eventid_templates.values())
uniq_testing_templates = list(testing_eventid_templates.values())

# %%
uniq_training_templates[:10]
# Out:
# [('instruction cache parity error corrected', [594, 620, 360, 92, 647]),
#  ('MidplaneSwitchController performing bit sparing on <*> bit <*>',
#   [10, 660, 577, 143, 587, 269, 143]),
#  ('generating <*>', [171]),
#  ('<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>',
#   [703, 782, 125, 643, 276, 647, 269, 680, 104, 143]),
#  ('<*> L3 EDRAM error s dcr <*> detected and corrected',
#   [510, 92, 125, 643, 276, 647]),
#  ('CE sym <*> at <*> mask <*>', [666, 4, 683, 494]),
#  ('total of <*> ddr error s detected and corrected',
#   [88, 636, 703, 92, 125, 643, 276, 647]),
#  ('ddr: activating redundant bit <*> rank <*> symbol <*>',
#   [703, 732, 724, 143, 680, 104]),
#  ('ddr: excessive soft failures consider replacing the card',
#   [703, 206, 749, 516, 463, 696, 128, 94]),
#  ('ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory',
#   [38, 623, 706, 137, 323, 326, 708, 627, 46, 380, 137, 69])]

# %%
uniq_testing_templates[:10]
# Out:
# [('idoproxydb has been started: Name: <*> Input parameters: -enableflush -loguserinfo db.properties BlueGene1',
#   [293, 356, 113, 345, 297, 402, 668, 711, 160, 544]),
#  ('ciodb has been restarted.', [293, 356, 646]),
#  ('mmcs_db_server has been started: <*> mmcs_db_server --useDatabase BGL --dbproperties <*> --iolog bgl BlueLight logs BGL --reconnect-blocks all',
#   [668,
#    416,
#    293,
#    356,
#    113,
#    668,
#    416,
#    398,
#    406,
#    797,
#    160,
#    325,
#    333,
#    797,
#    285,
#    759,
#    349]),
#  ('ciod: LOGIN chdir <*> <*> <*> <*> <*> failed: No such file or directory',
#   [663, 107, 480, 627, 46, 380, 137, 69]),
#  ('ciod: failed to read message prefix on control stream CioStream socket to <*>',
#   [480, 445, 499, 640, 786, 269, 427, 225, 182, 443, 453, 445]),
#  ('<*> L3 directory error s dcr <*> detected and corrected',
#   [510, 69, 92, 125, 643, 276, 647]),
#  ('data TLB error interrupt', [630, 578, 92, 765]),
#  ('machine check interrupt', [317, 405, 765]),
#  ('machine check status register: <*>', [317, 405, 410, 419]),
#  ('summary...........................1', [91])]

# %%
training_tokens_id = [entry[1] for entry in uniq_training_templates]
testing_tokens_id = [entry[1] for entry in uniq_testing_templates]

# %%
def templateEmbedding(tokens_id):
    '''
    Calculate template embedding by aggregating its tokens' embedding
    '''
    tokens_embedding = embedding_matrix[tokens_id]
    if len(tokens_id) == 0:
        return torch.sum(tokens_embedding, axis=0)
    return torch.mean(tokens_embedding, axis=0)

training_template_embeddings = torch.vstack([templateEmbedding(tokens_id) for tokens_id in training_tokens_id])
cosine_func = torch.nn.CosineSimilarity(dim=1, eps=1e-6)

def nearestTemplate(tokens_id):
    curr_embedding = templateEmbedding(tokens_id)
    cos_sim = cosine_func(training_template_embeddings, curr_embedding)
    _, top_k = torch.topk(cos_sim, 5)
    ret = []
    
    for entry in top_k.tolist():
        ret.append(uniq_training_templates[entry][0])
        
    return ret

# %%
for template, tokens_id in uniq_testing_templates:
    nearest_templates = nearestTemplate(tokens_id)
    print(f'Nearest templates of \n{template} \n are \n {nearest_templates}')
# Out:
# Nearest templates of
# idoproxydb has been started: Name: <*> Input parameters: -enableflush -loguserinfo db.properties BlueGene1
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected', '<*> L3 EDRAM error s dcr <*> detected and corrected']
# Nearest templates of
# ciodb has been restarted.
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected', '<*> L3 EDRAM error s dcr <*> detected and corrected', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# mmcs_db_server has been started: <*> mmcs_db_server --useDatabase BGL --dbproperties <*> --iolog bgl BlueLight logs BGL --reconnect-blocks all
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected', 'guaranteed data cache block touch........1']
# Nearest templates of
# ciod: LOGIN chdir <*> <*> <*> <*> <*> failed: No such file or directory
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# ciod: failed to read message prefix on control stream CioStream socket to <*>
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'ddr: excessive soft failures consider replacing the card', 'guaranteed data cache block touch........1']
# Nearest templates of
# <*> L3 directory error s dcr <*> detected and corrected
#  are
#  ['<*> L3 EDRAM error s dcr <*> detected and corrected', 'total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# data TLB error interrupt
#  are
#  ['instruction cache parity error corrected', 'rts internal error', 'guaranteed data cache block touch........1', 'external input interrupt <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# machine check interrupt
#  are
#  ['machine check <*>', 'machine state register: <*>', 'debug interrupt enable............0', 'critical input interrupt <*>', 'external input interrupt <*>']
# Nearest templates of
# machine check status register: <*>
#  are
#  ['machine state register: <*>', 'machine check <*>', 'core configuration register: <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# summary...........................1
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'data address: <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# instruction plb <*>
#  are
#  ['instruction address: <*>', 'instruction address space.........0', 'guaranteed instruction cache block touch.0', 'disable apu instruction broadcast........0', 'instruction cache parity error corrected']
# Nearest templates of
# data read plb <*>
#  are
#  ['data address: <*>', 'data address space................0', 'guaranteed data cache block touch........1', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# data write plb <*>
#  are
#  ['data address: <*>', 'data address space................0', 'guaranteed data cache block touch........1', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# tlb <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# i-cache parity error..............0
#  are
#  ['instruction cache parity error corrected', 'guaranteed data cache block touch........1', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected', 'rts internal error']
# Nearest templates of
# d-cache search parity <*>
#  are
#  ['instruction cache parity error corrected', 'guaranteed data cache block touch........1', 'guaranteed instruction cache block touch.0', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# d-cache flush parity <*>
#  are
#  ['instruction cache parity error corrected', 'guaranteed data cache block touch........1', 'guaranteed instruction cache block touch.0', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# imprecise machine <*>
#  are
#  ['machine check <*>', 'machine state register: <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: excessive soft failures consider replacing the card', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# <*> 5:00460000 6:00000000 <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 8:009f7120 9:00002670 10:009741e0 11:00000000
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# <*> <*> 18:00000000 19:00000000
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 20:00000000 <*> 22:00000000 <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 24:1fefff40 <*> 26:1fefff60 <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 28:30001460 29:30001510 30:00000000 31:30001400
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# <*> cr:20000000 xer:00000002 <*>
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', 'floating point instr. <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', 'rts internal error']
# Nearest templates of
# rts panic - stopping execution
#  are
#  ['<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'guaranteed instruction cache block touch.0', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# <*> torus receiver <*> <*> <*> error s dcr <*> detected and corrected
#  are
#  ['<*> L3 EDRAM error s dcr <*> detected and corrected', 'total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'instruction cache parity error corrected']
# Nearest templates of
# 4:0000000e 5:000865b0 <*> <*>
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '20:00008000 21:001e7e94 <*> <*>']
# Nearest templates of
# 24:0037d1e0 25:0000000e 26:000865b0 27:00089ae0
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '20:00008000 21:001e7e94 <*> <*>']
# Nearest templates of
# 12:48000828 13:1eeeeeee 14:001e9284 15:00000001
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff']
# Nearest templates of
# 16:1fe12838 17:00000000 18:001e7ea0 19:ffffffff
#  are
#  ['16:00000000 17:00000000 18:001e7ea0 19:ffffffff', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '20:00008000 21:001e7e94 <*> <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '<*> <*> 30:0000000e 31:000865b0']
# Nearest templates of
# ciod: Message code <*> is not <*> or <*>
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected', 'ddr: activating redundant bit <*> rank <*> symbol <*>']
# Nearest templates of
# ciod: pollControlDescriptors: Detected the debugger died.
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'MidplaneSwitchController performing bit sparing on <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# ciod: for node <*> read continuation request but ioState is <*>
#  are
#  ['<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# ciod: cpu <*> at treeaddr <*> sent unrecognized message <*>
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'guaranteed data cache block touch........1']
# Nearest templates of
# <*> <*> 2:1eeeeeee 3:00000000
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 4:00088750 5:00088740 <*> <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 8:00106810 9:0000146b 10:0ff00000 11:00088780
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 16:00000000 17:00089b10 18:00089b08 19:000887dc
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# <*> <*> 22:00000000 23:00000000
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 24:00082d70 25:00082d78 26:00000000 27:00082d78
#  are
#  ['<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> 9:00000000 10:00090000 11:0000003c']
# Nearest templates of
# 28:00040000 29:00000070 30:00082d78 31:00106720
#  are
#  ['<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> 9:00000000 10:00090000 11:0000003c']
# Nearest templates of
# <*> <*> xer:00000002 ctr:00000000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'problem state <*> sup <*> usr <*>', 'floating point instr. <*>', 'rts internal error', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# ciod: LOGIN chdir <*> <*> <*> <*> failed: Permission denied
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'disable apu instruction broadcast........0', 'guaranteed data cache block touch........1', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'guaranteed instruction cache block touch.0']
# Nearest templates of
# L3 global control register: <*>
#  are
#  ['core configuration register: <*>', 'machine state register: <*>', 'guaranteed data cache block touch........1', 'guaranteed instruction cache block touch.0', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# start <*>
#  are
#  ['wait state enable.................0', 'ddr: excessive soft failures consider replacing the card', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'debug wait enable.................0']
# Nearest templates of
# disable speculative access...............0
#  are
#  ['disable trace broadcast..................0', 'disable apu instruction broadcast........0', 'disable store gathering..................0', 'guaranteed data cache block touch........1', 'guaranteed instruction cache block touch.0']
# Nearest templates of
# close EDRAM pages as soon as possible....0
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'ddr: excessive soft failures consider replacing the card', 'total of <*> ddr error s detected and corrected', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# size of scratchpad portion of L3.........0 0M
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'total of <*> ddr error s detected and corrected', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# disable all access to cache directory....0
#  are
#  ['guaranteed data cache block touch........1', 'guaranteed instruction cache block touch.0', 'disable store gathering..................0', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'disable apu instruction broadcast........0']
# Nearest templates of
# write buffer commit threshold............2
#  are
#  ['guaranteed data cache block touch........1', 'wait state enable.................0', 'guaranteed instruction cache block touch.0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# size of DDR we are caching...............1 512M
#  are
#  ['<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: excessive soft failures consider replacing the card', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# prefetch depth for <*> <*>
#  are
#  ['icache prefetch <*>', 'guaranteed instruction cache block touch.0', 'guaranteed data cache block touch........1', 'instruction cache parity error corrected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# max number of outstanding prefetches.....7
#  are
#  ['total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: excessive soft failures consider replacing the card', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'guaranteed data cache block touch........1']
# Nearest templates of
# turn on hidden refreshes.................1
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'guaranteed data cache block touch........1', 'MidplaneSwitchController performing bit sparing on <*> bit <*>', 'guaranteed instruction cache block touch.0', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# disable write lines 2:4..................0
#  are
#  ['disable trace broadcast..................0', 'disable apu instruction broadcast........0', 'disable store gathering..................0', 'debug interrupt enable............0', 'debug wait enable.................0']
# Nearest templates of
# L3 ecc control register: <*>
#  are
#  ['machine state register: <*>', 'core configuration register: <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> L3 EDRAM error s dcr <*> detected and corrected', 'guaranteed data cache block touch........1']
# Nearest templates of
# capture first directory <*> error address..0
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'data address: <*>', 'data address space................0', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# capture first EDRAM <*> error address..0
#  are
#  ['total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'data address: <*>', '<*> L3 EDRAM error s dcr <*> detected and corrected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# capture first DDR uncorrectable error address..0
#  are
#  ['total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'instruction cache parity error corrected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'data address: <*>']
# Nearest templates of
# disable flagging of DDR UE s as major internal error.0
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: excessive soft failures consider replacing the card', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# L3 ecc status register: <*>
#  are
#  ['machine state register: <*>', 'core configuration register: <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>', '<*> L3 EDRAM error s dcr <*> detected and corrected']
# Nearest templates of
# correctable error detected in <*> <*>
#  are
#  ['<*> L3 EDRAM error s dcr <*> detected and corrected', 'total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'instruction cache parity error corrected', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# uncorrectable error detected in <*> <*>
#  are
#  ['total of <*> ddr error s detected and corrected', '<*> L3 EDRAM error s dcr <*> detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'instruction cache parity error corrected', 'rts internal error']
# Nearest templates of
# parity error in <*> <*>
#  are
#  ['instruction cache parity error corrected', 'total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> L3 EDRAM error s dcr <*> detected and corrected', 'rts internal error']
# Nearest templates of
# number of correctable errors detected in L3 <*>
#  are
#  ['<*> L3 EDRAM error s dcr <*> detected and corrected', 'total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# interrupt threshold...0
#  are
#  ['critical input interrupt <*>', 'external input interrupt <*>', 'debug interrupt enable............0', 'guaranteed data cache block touch........1', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# number of lines with parity errors written to L3 <*>
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected', '<*> L3 EDRAM error s dcr <*> detected and corrected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# DDR machine check register: <*> <*>
#  are
#  ['machine state register: <*>', 'machine check <*>', 'core configuration register: <*>', 'guaranteed data cache block touch........1', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# memory and bus summary...........................0
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'guaranteed data cache block touch........1', 'guaranteed instruction cache block touch.0']
# Nearest templates of
# command manager unit summary.....................0
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'force load store alignment...............0']
# Nearest templates of
# memory manager uncorrectable <*>
#  are
#  ['instruction cache parity error corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# memory manager strobe gate.......................0
#  are
#  ['<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'guaranteed data cache block touch........1', 'force load store alignment...............0', 'MidplaneSwitchController performing bit sparing on <*> bit <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# memory manager address <*> <*>
#  are
#  ['data address: <*>', 'data address space................0', 'instruction address space.........0', 'instruction address: <*>', 'guaranteed data cache block touch........1']
# Nearest templates of
# memory manager <*>
#  are
#  ['guaranteed data cache block touch........1', 'force load store alignment...............0', 'guaranteed instruction cache block touch.0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'MidplaneSwitchController performing bit sparing on <*> bit <*>']
# Nearest templates of
# memory manager store buffer parity...............0
#  are
#  ['force load store alignment...............0', 'guaranteed data cache block touch........1', 'instruction cache parity error corrected', 'guaranteed instruction cache block touch.0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# memory manager RMW buffer parity.................0
#  are
#  ['instruction cache parity error corrected', 'guaranteed data cache block touch........1', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'force load store alignment...............0', 'guaranteed instruction cache block touch.0']
# Nearest templates of
# memory manager refresh <*> <*>
#  are
#  ['guaranteed data cache block touch........1', 'guaranteed instruction cache block touch.0', 'force load store alignment...............0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'instruction cache parity error corrected']
# Nearest templates of
# state machine....................................0
#  are
#  ['machine state register: <*>', 'machine check <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# memory manager command manager address parity..0
#  are
#  ['instruction cache parity error corrected', 'guaranteed data cache block touch........1', 'instruction address space.........0', 'data address space................0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# regctl scancom interface.........................0
#  are
#  ['core configuration register: <*>', 'data address space................0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'guaranteed data cache block touch........1']
# Nearest templates of
# DDR failing info register: <*>
#  are
#  ['machine state register: <*>', 'core configuration register: <*>', 'guaranteed data cache block touch........1', 'ddr: excessive soft failures consider replacing the card', 'ddr: activating redundant bit <*> rank <*> symbol <*>']
# Nearest templates of
# capture <*>
#  are
#  ['disable store gathering..................0', 'disable trace broadcast..................0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'critical input interrupt <*>', 'guaranteed data cache block touch........1']
# Nearest templates of
# symbol................15
#  are
#  ['ddr: activating redundant bit <*> rank <*> symbol <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'CE sym <*> at <*> mask <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# mask..................0x40
#  are
#  ['CE sym <*> at <*> mask <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# miscompare............0
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# uncorrectable <*>
#  are
#  ['total of <*> ddr error s detected and corrected', 'instruction cache parity error corrected', 'rts internal error', '<*> L3 EDRAM error s dcr <*> detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# address parity error..0
#  are
#  ['instruction cache parity error corrected', 'data address: <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'data address space................0', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# correctable <*>
#  are
#  ['<*> L3 EDRAM error s dcr <*> detected and corrected', 'total of <*> ddr error s detected and corrected', 'instruction cache parity error corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# qw trapped............0
#  are
#  ['total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'floating point instr. <*>']
# Nearest templates of
# chip select...........0
#  are
#  ['ddr: excessive soft failures consider replacing the card', 'guaranteed data cache block touch........1', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'disable store gathering..................0', 'guaranteed instruction cache block touch.0']
# Nearest templates of
# DDR failing data registers: <*> <*>
#  are
#  ['machine state register: <*>', 'general purpose registers:', 'core configuration register: <*>', 'special purpose registers:', 'guaranteed data cache block touch........1']
# Nearest templates of
# <*> <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# DDR failing address register: <*> <*>
#  are
#  ['machine state register: <*>', 'core configuration register: <*>', 'data address: <*>', 'instruction address: <*>', 'instruction address space.........0']
# Nearest templates of
# 4:00000000 5:00000000 <*> <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# <*> 9:00000001 10:1fe00000 <*>
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', 'floating pt ex mode <*> <*>']
# Nearest templates of
# 16:00558630 17:00089b10 18:00089b08 19:000887fc
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 20:fffffff4 21:00000008 22:00000004 23:00000001
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 24:00000007 25:ffffffff 26:00089ae0 27:000894a4
#  are
#  ['24:00000000 <*> 26:000865b0 27:00089ae0', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: excessive soft failures consider replacing the card', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 28:00040000 29:00000000 30:00090000 31:00000000
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# lr:0000846c cr:48004242 xer:00000002 ctr:029ad752
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> 9:00000000 10:00090000 11:0000003c', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1feaa238 <*>']
# Nearest templates of
# PrepareForService is being done on this <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> <*> by <*>
#  are
#  ['<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'total of <*> ddr error s detected and corrected', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'MidplaneSwitchController performing bit sparing on <*> bit <*>']
# Nearest templates of
# PrepareForService shutting down <*> mLctn <*> mCardSernum <*> mLp <*> mIp <*> mType <*> as part of Service Action <*>
#  are
#  ['<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'total of <*> ddr error s detected and corrected', '<*> L3 EDRAM error s dcr <*> detected and corrected']
# Nearest templates of
# EndServiceAction is restarting the <*> in <*> <*> as part of Service Action <*>
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'MidplaneSwitchController performing bit sparing on <*> bit <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# EndServiceAction <*> performed upon <*> by <*>
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'MidplaneSwitchController performing bit sparing on <*> bit <*>', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# Node card is not fully functional
#  are
#  ['ddr: excessive soft failures consider replacing the card', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'ddr: activating redundant bit <*> rank <*> symbol <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# Can not get assembly information for node card
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'ddr: excessive soft failures consider replacing the card', 'ddr: activating redundant bit <*> rank <*> symbol <*>']
# Nearest templates of
# Node card status: <*> <*> are active. Clock Mode is Low. Clock Select is Midplane. Phy JTAG Reset is asserted. ASIC JTAG Reset is asserted. Temperature <*> is not active. No temperature error. Temperature Limit Error Latch is clear. PGOOD <*> <*> <*> PGOOD <*> <*> <*> <*> MPGOOD <*> <*> OK. MPGOOD <*> <*> <*> <*> <*> <*> <*> <*> is OK. <*> <*> <*> <*> is OK.
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected', 'MidplaneSwitchController performing bit sparing on <*> bit <*>']
# Nearest templates of
# Node card VPD check: <*> node in processor card slot <*> <*> <*> <*> VPD ecid <*> <*> <*>
#  are
#  ['ddr: excessive soft failures consider replacing the card', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# ciod: sendMsgToDebugger: error sending PROGRAM_EXITED message to debugger.
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'disable apu instruction broadcast........0', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# 4:00055920 5:00055910 6:00009338 7:00000000
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 8:00015630 9:00045142 10:03389d21 11:000107fd
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 12:000558a0 13:1eeeeeee 14:0178fa90 15:0002ac00
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# 20:00000000 21:00000001 22:00085e70 23:00085fd8
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 24:00085fdc 25:00000000 26:00000000 <*>
#  are
#  ['general purpose registers:', 'force load store alignment...............0', 'icache prefetch <*>', 'guaranteed data cache block touch........1', '0:00000000 <*> 2:1eeeeeee <*>']
# Nearest templates of
# 28:00000000 29:03384ef0 30:00040000 31:00040220
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff']
# Nearest templates of
# lr:0000b20c cr:40002424 xer:00000002 ctr:000095e0
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 4:00085fd8 5:000865b0 <*> <*>
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 8:00088880 9:00000400 <*> 11:c0018000
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# <*> 13:1eeeeeee 14:2e8ba2e9 <*>
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# 16:0000055f 17:0c5cc1e0 18:00000001 19:04ed1b98
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> 9:00000000 10:00090000 11:0000003c']
# Nearest templates of
# 20:000012c0 21:0000055f 22:00000000 23:04ecf0a0
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# <*> 25:00000008 26:000865b0 <*>
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# <*> 29:000000e3 <*> 31:00000001
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff']
# Nearest templates of
# lr:0000ea38 cr:84404442 xer:00000002 ctr:0000024b
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# 0:00000002 1:1fea8640 2:1eeeeeee 3:fe9bc000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '24:00000000 <*> 26:000865b0 27:00089ae0', 'CE sym <*> at <*> mask <*>']
# Nearest templates of
# 4:00439430 5:ffff96e0 6:fffbccf0 7:0f554c48
#  are
#  ['<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '20:00008000 21:001e7e94 <*> <*>']
# Nearest templates of
# 8:0f4c4108 9:0d563fc0 10:0d7679b8 11:05681130
#  are
#  ['<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> 9:00000000 10:00090000 11:0000003c', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 12:0d7007b8 13:1eeeeeee 14:00000015 15:fe9bc000
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 16:00364380 17:00440000 18:05fb0d70 19:05f6da60
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 20:004d96ac 21:0d6323c0 22:07bd4840 23:0567a810
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '<*> 9:00000000 10:00090000 11:0000003c', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>']
# Nearest templates of
# 24:09218840 25:00000001 26:004e0000 27:0a154900
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff']
# Nearest templates of
# 28:0007d000 29:0b798900 30:00067200 31:00090b40
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# <*> <*> xer:20000002 ctr:00000001
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'problem state <*> sup <*> usr <*>', 'floating point instr. <*>', 'rts internal error', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# <*> torus sender <*> <*> error s dcr <*> detected and corrected
#  are
#  ['<*> L3 EDRAM error s dcr <*> detected and corrected', 'total of <*> ddr error s detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'instruction cache parity error corrected']
# Nearest templates of
# L3 correctable errors exceeds threshold iar <*> lr <*>
#  are
#  ['total of <*> ddr error s detected and corrected', '<*> L3 EDRAM error s dcr <*> detected and corrected', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> tree receiver <*> in re-synch state event s dcr <*> detected']
# Nearest templates of
# 0:0007d000 1:1fea8670 2:1eeeeeee 3:00439130
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 4:00000fc5 5:0007d000 6:fffa8840 7:0006d600
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 8:0006d600 9:00591040 10:00591040 11:0dfc8330
#  are
#  ['<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> 9:00000000 10:00090000 11:0000003c']
# Nearest templates of
# 12:0daa7b28 13:1eeeeeee 14:ffa94800 15:00000007
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# 16:069df3b0 17:06b563b0 18:066ccbc0 19:004d8f30
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 20:0deed738 21:0d9ccf30 22:0f5ef850 23:0f572850
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# 24:0f6e9850 25:0daa7b30 26:0f66c850 27:0df5ad38
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248']
# Nearest templates of
# 28:0da3a530 29:059674c0 30:0dfc8338 31:0e110530
#  are
#  ['<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '20:00008000 21:001e7e94 <*> <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# <*> <*> xer:20000002 ctr:00000002
#  are
# ...
# Nearest templates of
# fpr0 <*> <*> <*> 3ff00000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'floating pt ex mode <*> <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'problem state <*> sup <*> usr <*>', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr1 <*> <*> <*> 3fe00000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'floating pt ex mode <*> <*>', 'rts internal error', 'problem state <*> sup <*> usr <*>', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# fpr2 <*> 3e458839 d9d7bdbb 3ddb7cdf
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr3 <*> 3fc86af6 d9d7bdbb 3ddb7cdf
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr5 <*> 3fefabb7 84dc4fe1 3f0e019c
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr6 <*> c006dde7 84dc4fe1 3fce019c
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '<*> 9:00000000 10:00090000 11:0000003c', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> <*> 30:0000000e 31:000865b0']
# Nearest templates of
# fpr7 <*> <*> 585fa747 3fe6dba1
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '24:00000000 <*> 26:000865b0 27:00089ae0', 'problem state <*> sup <*> usr <*>']
# Nearest templates of
# fpr8 <*> 3fc8b161 b605c900 bf718d1a
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> 9:00000000 10:00090000 11:0000003c', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr9 <*> 4000efff 3b301df2 bff30219
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '24:00000000 <*> 26:000865b0 27:00089ae0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0']
# Nearest templates of
# fpr11 <*> 3e45652e <*> 3ff00000
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff']
# Nearest templates of
# fpr13 <*> 4000c8d0 128cfca0 3fa0a96f
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> 9:00000000 10:00090000 11:0000003c', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248']
# Nearest templates of
# fpr2 <*> 17002a83 78d4fdf3 4043a6e9
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# fpr3 <*> <*> a0000000 bfbb9c2b
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr4 <*> 3fe99999 a0000000 40037e17
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '20:00008000 21:001e7e94 <*> <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0']
# Nearest templates of
# fpr5 <*> 42c80000 <*> 3fd31b6b
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '24:00000000 <*> 26:000865b0 27:00089ae0', '<*> 9:00000000 10:00090000 11:0000003c']
# Nearest templates of
# fpr6 <*> <*> <*> 3fe6c3eb
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> 9:00000000 10:00090000 11:0000003c', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr7 <*> 40b11ceb <*> 3fe04888
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1feaa238 <*>']
# Nearest templates of
# fpr8 <*> 3ff36523 e0000000 3fba0da6
#  are
#  ['20:00008000 21:001e7e94 <*> <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>']
# Nearest templates of
# fpr9 <*> <*> 4ccccccc 3fe6c3eb
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> 9:00000000 10:00090000 11:0000003c', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr10 <*> <*> <*> 3fa99999
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '24:00000000 <*> 26:000865b0 27:00089ae0', 'floating pt ex mode <*> <*>', 'problem state <*> sup <*> usr <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# fpr11 <*> <*> <*> bf144000
#  are
#  ['problem state <*> sup <*> usr <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'floating pt ex mode <*> <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', 'floating point instr. <*>']
# Nearest templates of
# fpr13 <*> 00006a83 29ee437c 3feb932c
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0']
# Nearest templates of
# ciod: for node <*> incomplete data written to core file <*>
#  are
#  ['ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '<*> tree receiver <*> in re-synch state event s dcr <*> detected', 'guaranteed data cache block touch........1', 'total of <*> ddr error s detected and corrected']
# Nearest templates of
# fpr1 <*> 3fd0da8e <*> <*>
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '20:00008000 21:001e7e94 <*> <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>']
# Nearest templates of
# fpr2 <*> 20001c84 8e38e38e 403b38e3
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '20:00008000 21:001e7e94 <*> <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# fpr5 <*> <*> <*> bfd40000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'problem state <*> sup <*> usr <*>', 'rts internal error', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# fpr6 <*> 40623f66 <*> 3fd80000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '24:00000000 <*> 26:000865b0 27:00089ae0', 'rts internal error', 'problem state <*> sup <*> usr <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# fpr9 <*> 3f6b745f <*> <*>
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr11 <*> <*> 4fcf28c8 406162a6
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>']
# Nearest templates of
# fpr12 <*> <*> ea65a5d2 407275e5
#  are
#  ['16:00000000 17:00089b10 18:001e7ea0 19:00000001', '16:00000000 17:00000000 18:001e7ea0 19:ffffffff', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248']
# Nearest templates of
# fpr13 <*> 06001c94 53eb915a 4088ed0d
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr0 <*> 20000b21 040c0000 <*>
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr11 <*> 408bead8 b363781c 405246f3
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> 9:00000000 10:00090000 11:0000003c', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr12 <*> 4035edde <*> <*>
#  are
#  ['total of <*> ddr error s detected and corrected', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', 'problem state <*> sup <*> usr <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# fpr1 <*> <*> <*> 3fbb3328
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'problem state <*> sup <*> usr <*>', 'rts internal error', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'ddr: excessive soft failures consider replacing the card']
# Nearest templates of
# fpr4 <*> <*> <*> 3ff80000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'floating pt ex mode <*> <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'problem state <*> sup <*> usr <*>', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr5 <*> <*> <*> 3ff00000
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'floating pt ex mode <*> <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>', 'problem state <*> sup <*> usr <*>', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr6 <*> <*> c21003e6 bfb0bf8d
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr7 <*> <*> cb99f519 bc7ae242
#  are
#  ['24:00000000 <*> 26:000865b0 27:00089ae0', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0']
# Nearest templates of
# fpr8 <*> <*> 3145c070 3c5a6263
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr9 <*> <*> fa52ad9f 3fecfc6c
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>']
# Nearest templates of
# fpr10 <*> <*> <*> 3fdb1d83
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr11 <*> <*> <*> 3c7c0000
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr12 <*> <*> 2631e9c3 3fed0893
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '<*> 9:00000000 10:00090000 11:0000003c', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# fpr13 <*> <*> 72a74c77 bf5863cb
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '<*> 9:00000000 10:00090000 11:0000003c', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> <*> 30:0000000e 31:000865b0']
# Nearest templates of
# fpr0 <*> <*> 00000dad 40e41b10
#  are
#  ['<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr1 <*> <*> <*> 3fd33333
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'problem state <*> sup <*> usr <*>', 'rts internal error', '24:00000000 <*> 26:000865b0 27:00089ae0', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory']
# Nearest templates of
# fpr3 <*> <*> 4dd1f32b 400bcf13
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '24:00000000 <*> 26:000865b0 27:00089ae0']
# Nearest templates of
# fpr4 <*> <*> f4041f2f 40b7cafc
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr5 <*> <*> 69555a6a 40b7cbf3
#  are
#  ['ddr: excessive soft failures consider replacing the card', 'ciod: Error loading <*> <*> <*> <*> <*> <*> invalid or missing program image No such file or directory', '<*> ddr errors s detected and corrected on rank <*> symbol <*> bit <*>', '4:0000000e 5:000865b0 6:1fea7b68 <*>', 'ddr: activating redundant bit <*> rank <*> symbol <*>']
# Nearest templates of
# fpr6 <*> <*> 7fba6c5d bfca0fcc
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', '<*> 9:00000000 10:00090000 11:0000003c', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>']
# Nearest templates of
# fpr7 <*> 42c80000 1dea4cc8 3c5e9184
#  are
#  ['<*> 9:00000000 10:00090000 11:0000003c', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr9 <*> 40a4e7cf 800e99b1 3fefcf0c
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '20:00008000 21:001e7e94 <*> <*>']
# Nearest templates of
# fpr10 <*> 3fe8a2f4 8568391d 3fbbf1b7
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', 'lr:0000d9ac <*> xer:00000002 ctr:0000e248', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr11 <*> <*> <*> bc88dc00
#  are
#  ['lr:0000d9ac <*> xer:00000002 ctr:0000e248', 'problem state <*> sup <*> usr <*>', 'CE sym <*> at <*> mask <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', '4:0000000e 5:000865b0 6:1fea7b68 <*>']
# Nearest templates of
# fpr12 <*> <*> b01b7264 3fefcd42
#  are
#  ['4:0000000e 5:000865b0 6:1fea7b68 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1feaa238 <*>', '24:00000000 <*> 26:000865b0 27:00089ae0', '16:00000000 17:00089b10 18:001e7ea0 19:00000001']
# Nearest templates of
# fpr13 <*> 0000359d f1e75989 3f2c5b7b
#  are
#  ['4:0000000e 5:000865b0 6:1feaa238 <*>', '<*> <*> 30:0000000e 31:000865b0', '4:0000000e 5:000865b0 6:1fea7b68 <*>', '16:00000000 17:00089b10 18:001e7ea0 19:00000001', '<*> 9:00000000 10:00090000 11:0000003c']
